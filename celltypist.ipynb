# %%
import scanpy as sc
import celltypist
from celltypist import models

# %%
adata_2000 = sc.read('single_.h5ad')

# %%
adata_2000.obs
# Out:
#                                orig.ident  nCount_RNA  nFeature_RNA  \
# patient1__AAACCTGAGCGGATCA.1      GASTRIC      1123.0           638
# patient1__AAACCTGCATCTGGTA.1      GASTRIC      1481.0           632
# patient1__AAACCTGGTAAGTGTA.1      GASTRIC       983.0           557
# patient1__AAACCTGGTAGCTGCC.1      GASTRIC      1104.0           618
# patient1__AAACCTGTCCTTTACA.1      GASTRIC      3335.0          1268
# ...                                   ...         ...           ...
# patient13__TTTGGTTGTGCAGACA.14    GASTRIC      6100.0          1891
# patient13__TTTGGTTTCGCCTGAG.14    GASTRIC     22216.0          3762
# patient13__TTTGTCAGTCTTTCAT.14    GASTRIC     10137.0          2432
# patient13__TTTGTCATCTCACATT.14    GASTRIC     29013.0          4627
# patient13__TTTGTCATCTGCAGTA.14    GASTRIC     10404.0          2966
#
#                                   Patient              Barcode type  \
# patient1__AAACCTGAGCGGATCA.1     patient1   AAACCTGAGCGGATCA.1  NAG
# ...

# %%
import celltypist
predictions = celltypist.annotate(adata_2000, model = 'Immune_All_High.pkl', majority_voting = True)
# Out:
# 🔬 Input data has 32307 cells and 20778 genes
# 🔗 Matching reference genes in the model
# 🧬 5069 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 15
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!

# %%
predictions.predicted_labels.to_csv('celltypist.csv')

# %%
len(predictions.predicted_labels)
# Out:
# 32307
